# %%
from netgen.meshing import *
from ngsolve import *
from netgen.meshing import Mesh as NGMesh
from ngsolve.webgui import Draw
from netgen.geom2d import SplineGeometry, unit_square
import matplotlib.pyplot as plt
import numpy as np
import pickle
# Bem. stiw: unnötig wird in Zeile 2 schon geladen
#from ngsolve import CoefficientFunction
from ngsolve.meshes import MakeStructured2DMesh
import time

# %% [markdown]
# Hier wird eine lineare Funktion verwendet, um alle Werte von -1.5 bis 1.5 drin zu haben.

# %%
def fun(x):
    return -2+4*x

# x nicht überschreiben, das ist unsere CF für die Koordinaten...
xp = np.linspace(0,1,400)
fun_x = fun(xp)

# %%
plt.plot(xp,fun_x, label='f(x)=x')
plt.legend()
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %%
#print(fun_x)

# %%
# generate a 1D mesh
ngmesh = NGMesh()
ngmesh.dim = 1

# Bem. stiw: wir brauchen etwas mehr Elemente als nur eines
nel = 200
l0 = 2

pnums = []
for i in range(0, nel+1):
    pnums.append (ngmesh.Add(MeshPoint (Pnt(i/nel*l0, 0, 0))))

for i in range(0,nel):
    ngmesh.Add (Element1D([pnums[i],pnums[i+1]], index=1))

ngmesh.Add (Element0D(pnums[0], index=1))
ngmesh.Add (Element0D(pnums[nel], index=2))

mesh = Mesh(ngmesh)

# %%
# Startwerte:
t0 = 0
dt0 = 2.5e-1
tend = 2
eps0 = 1e-6
d2t = 0.000  #Änderungsrate für dt

# Initialisierung der Parameter
t = Parameter (t0)
dt = Parameter (dt0)
eps = Parameter (eps0)

# %%
order = 2
V = H1(mesh, order=order)

# %%
# List für die gfu's initialisieren
gfu_array = []

for p in range (2,7):
    eps.Set(10**(-p))
    t.Set(t0)

    u = V.TrialFunction()
    v = V.TestFunction()
    gfu = GridFunction(V)
    a = BilinearForm (V, symmetric = False)
    a += Variation((eps/2*grad(u)*grad(u) 
                   +(u**2*(1-u*u)**2)
                   + 0.5/dt*(u-gfu)**2)*dx)
    
    # Interpolate the function onto the finite element space
    # Bem. stiw: hier können wir die Koordinaten CF benutzen
    u0 = GridFunction(V)
    u0.Set(-2+4*x)
    #oder
    u0.Set(fun(x))
    
    # Set the initial condition on the GridFunction
    gfu.Set(-2+4*x)
    


    
    res = gfu.vec.CreateVector()
    du = gfu.vec.CreateVector()
    
    # Newton Verfahren:
    start_time = time.time()
    for it in range(20):
        print("Newton iteration", it)
    
        # lösen des linearisierten Problems:
        # F(u_n)
        a.Apply (gfu.vec, res)
    
        # F'(u_n)
        a.AssembleLinearization(gfu.vec)
    
        #du.vec.data = a.mat.Inverse(V.FreeDofs(), inverse="umfpack") * res.vec
        #du.vec.data= a * res
        du.data = a.mat.Inverse(V.FreeDofs(), inverse="umfpack") * res
    
        # update gfu
        # u_n+1 = u_n - du
        gfu.vec.data -= du
    
        # eps für nächsten Zeitschritt updaten
        #eps.Set(eps.Get() * 1e-0)
        print("eps:", eps.Get())
    
        # Aktuelle Zeit updaten
        t += dt.Get()
        print("Seconds passed: ", t.Get())
    
        # Abbruchkriterium: nach 2 Sekunden (wie in Aufgabenstellung beschrieben)
        print(t)
        if t >= tend:
            break
    
        # dt für nächsten Schritt updaten
        dt.Set(dt.Get() + d2t)
        print("dt für nächste Iteration: ", dt.Get())
    
        # Abbruchkriterium: wenn es vor schon vor Ablauf der 2 Sekunden konvergiert
        stopcritval = sqrt(abs(InnerProduct(du,res)))
        print ("<A u",it,", A u",it,">_{-1}A0.S = ", stopcritval)
        print(gfu)
        if stopcritval < 1e-13:
            break
    end_time = time.time()
    time_to_compute = end_time - start_time
    
    #gfu_array = np.concatenate((gfu_array, [gfu]), axis=0)
    gfu_array.append(gfu)
# Out:
# Newton iteration 0
# eps: 0.01
# Seconds passed:  0.25
# ParameterCF, val = 0.25
#
# dt für nächste Iteration:  0.25
# <A u 0 , A u 0 >_{-1}A0.S =  105.57147469792713
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 1
# eps: 0.01
# Seconds passed:  0.5
# ParameterCF, val = 0.5
#
# dt für nächste Iteration:  0.25
# <A u 1 , A u 1 >_{-1}A0.S =  53.781129893576356
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 2
# eps: 0.01
# Seconds passed:  0.75
# ParameterCF, val = 0.75
#
# dt für nächste Iteration:  0.25
# <A u 2 , A u 2 >_{-1}A0.S =  27.31777839453566
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 3
# eps: 0.01
# Seconds passed:  1.0
# ParameterCF, val = 1
#
# dt für nächste Iteration:  0.25
# <A u 3 , A u 3 >_{-1}A0.S =  13.811151659320469
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 4
# eps: 0.01
# Seconds passed:  1.25
# ParameterCF, val = 1.25
#
# dt für nächste Iteration:  0.25
# <A u 4 , A u 4 >_{-1}A0.S =  6.929977902997351
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 5
# eps: 0.01
# Seconds passed:  1.5
# ParameterCF, val = 1.5
#
# dt für nächste Iteration:  0.25
# <A u 5 , A u 5 >_{-1}A0.S =  3.4346356094808477
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 6
# eps: 0.01
# Seconds passed:  1.75
# ParameterCF, val = 1.75
#
# dt für nächste Iteration:  0.25
# <A u 6 , A u 6 >_{-1}A0.S =  1.6682534884469928
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 7
# eps: 0.01
# Seconds passed:  2.0
# ParameterCF, val = 2
#
# Newton iteration 0
# eps: 0.001
# Seconds passed:  0.25
# ParameterCF, val = 0.25
#
# dt für nächste Iteration:  0.25
# <A u 0 , A u 0 >_{-1}A0.S =  105.57106389797612
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 1
# eps: 0.001
# Seconds passed:  0.5
# ParameterCF, val = 0.5
#
# dt für nächste Iteration:  0.25
# <A u 1 , A u 1 >_{-1}A0.S =  53.78081362627276
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 2
# eps: 0.001
# Seconds passed:  0.75
# ParameterCF, val = 0.75
#
# dt für nächste Iteration:  0.25
# <A u 2 , A u 2 >_{-1}A0.S =  27.31748258735456
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 3
# eps: 0.001
# Seconds passed:  1.0
# ParameterCF, val = 1
#
# dt für nächste Iteration:  0.25
# <A u 3 , A u 3 >_{-1}A0.S =  13.810850723785615
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 4
# eps: 0.001
# Seconds passed:  1.25
# ParameterCF, val = 1.25
#
# dt für nächste Iteration:  0.25
# <A u 4 , A u 4 >_{-1}A0.S =  6.929656315050287
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 5
# eps: 0.001
# Seconds passed:  1.5
# ParameterCF, val = 1.5
#
# dt für nächste Iteration:  0.25
# <A u 5 , A u 5 >_{-1}A0.S =  3.4342802716735035
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 6
# eps: 0.001
# Seconds passed:  1.75
# ParameterCF, val = 1.75
#
# dt für nächste Iteration:  0.25
# <A u 6 , A u 6 >_{-1}A0.S =  1.6678729613465737
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 7
# eps: 0.001
# Seconds passed:  2.0
# ParameterCF, val = 2
#
# Newton iteration 0
# eps: 0.0001
# Seconds passed:  0.25
# ParameterCF, val = 0.25
#
# dt für nächste Iteration:  0.25
# <A u 0 , A u 0 >_{-1}A0.S =  105.5710349947575
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 1
# eps: 0.0001
# Seconds passed:  0.5
# ParameterCF, val = 0.5
#
# dt für nächste Iteration:  0.25
# <A u 1 , A u 1 >_{-1}A0.S =  53.780805847149985
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 2
# eps: 0.0001
# Seconds passed:  0.75
# ParameterCF, val = 0.75
#
# dt für nächste Iteration:  0.25
# <A u 2 , A u 2 >_{-1}A0.S =  27.317486352461895
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 3
# eps: 0.0001
# Seconds passed:  1.0
# ParameterCF, val = 1
#
# dt für nächste Iteration:  0.25
# <A u 3 , A u 3 >_{-1}A0.S =  13.810857124692813
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 4
# eps: 0.0001
# Seconds passed:  1.25
# ParameterCF, val = 1.25
#
# dt für nächste Iteration:  0.25
# <A u 4 , A u 4 >_{-1}A0.S =  6.929660067247931
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 5
# eps: 0.0001
# Seconds passed:  1.5
# ParameterCF, val = 1.5
#
# dt für nächste Iteration:  0.25
# <A u 5 , A u 5 >_{-1}A0.S =  3.4342791433432707
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 6
# eps: 0.0001
# Seconds passed:  1.75
# ParameterCF, val = 1.75
#
# dt für nächste Iteration:  0.25
# <A u 6 , A u 6 >_{-1}A0.S =  1.6678681725027256
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 7
# eps: 0.0001
# Seconds passed:  2.0
# ParameterCF, val = 2
#
# Newton iteration 0
# eps: 1e-05
# Seconds passed:  0.25
# ParameterCF, val = 0.25
#
# dt für nächste Iteration:  0.25
# <A u 0 , A u 0 >_{-1}A0.S =  105.57103318181682
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 1
# eps: 1e-05
# Seconds passed:  0.5
# ParameterCF, val = 0.5
#
# dt für nächste Iteration:  0.25
# <A u 1 , A u 1 >_{-1}A0.S =  53.78081031659891
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 2
# eps: 1e-05
# Seconds passed:  0.75
# ParameterCF, val = 0.75
#
# dt für nächste Iteration:  0.25
# <A u 2 , A u 2 >_{-1}A0.S =  27.31749873415455
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 3
# eps: 1e-05
# Seconds passed:  1.0
# ParameterCF, val = 1
#
# dt für nächste Iteration:  0.25
# <A u 3 , A u 3 >_{-1}A0.S =  13.81087841092834
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 4
# eps: 1e-05
# Seconds passed:  1.25
# ParameterCF, val = 1.25
#
# dt für nächste Iteration:  0.25
# <A u 4 , A u 4 >_{-1}A0.S =  6.929687559863892
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 5
# eps: 1e-05
# Seconds passed:  1.5
# ParameterCF, val = 1.5
#
# dt für nächste Iteration:  0.25
# <A u 5 , A u 5 >_{-1}A0.S =  3.4343028124321595
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 6
# eps: 1e-05
# Seconds passed:  1.75
# ParameterCF, val = 1.75
#
# dt für nächste Iteration:  0.25
# <A u 6 , A u 6 >_{-1}A0.S =  1.6678876110292844
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 7
# eps: 1e-05
# Seconds passed:  2.0
# ParameterCF, val = 2
#
# Newton iteration 0
# eps: 1e-06
# Seconds passed:  0.25
# ParameterCF, val = 0.25
#
# dt für nächste Iteration:  0.25
# <A u 0 , A u 0 >_{-1}A0.S =  105.57103303217157
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 1
# eps: 1e-06
# Seconds passed:  0.5
# ParameterCF, val = 0.5
#
# dt für nächste Iteration:  0.25
# <A u 1 , A u 1 >_{-1}A0.S =  53.78081133305382
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 2
# eps: 1e-06
# Seconds passed:  0.75
# ParameterCF, val = 0.75
#
# dt für nächste Iteration:  0.25
# <A u 2 , A u 2 >_{-1}A0.S =  27.317502197402757
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 3
# eps: 1e-06
# Seconds passed:  1.0
# ParameterCF, val = 1
#
# dt für nächste Iteration:  0.25
# <A u 3 , A u 3 >_{-1}A0.S =  13.810888346739318
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 4
# eps: 1e-06
# Seconds passed:  1.25
# ParameterCF, val = 1.25
#
# dt für nächste Iteration:  0.25
# <A u 4 , A u 4 >_{-1}A0.S =  6.929715060735073
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 5
# eps: 1e-06
# Seconds passed:  1.5
# ParameterCF, val = 1.5
#
# dt für nächste Iteration:  0.25
# <A u 5 , A u 5 >_{-1}A0.S =  3.434315383667697
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 6
# eps: 1e-06
# Seconds passed:  1.75
# ParameterCF, val = 1.75
#
# dt für nächste Iteration:  0.25
# <A u 6 , A u 6 >_{-1}A0.S =  1.667897956151026
# gridfunction 'gfu' on space 'H1HighOrderFESpace(h1ho)'
# nested = 1
# autoupdate = 0
#
# Newton iteration 7
# eps: 1e-06
# Seconds passed:  2.0
# ParameterCF, val = 2

# %%
for p in range(len(gfu_array)):
    plt.plot(xp,gfu_array[p](mesh(xp)).flatten(), label=f'eps 10^(-{p+2})')


plt.legend()
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
